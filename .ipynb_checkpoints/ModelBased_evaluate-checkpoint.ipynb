# %%
import matplotlib.pyplot as plt
import MFModel
import MLPModel
import MFMLPModel
# Out:
# Using TensorFlow backend.

# %%
M1 = MFModel.MFModel()

# %%
M1.eval()
# Out:
# MF model test err = 1.1158908942924153

# %%
M1.pplot()

# %%
M2 = MLPModel.MLPModel(epochs=30)

# %%
M2.eval()
# Out:
# MLP Model test err = 0.8817833194572684

# %%
M2.pplot()

# %%
M3 = MFMLPModel.MFMLPModel(epochs=30, mf_latent=8, learning_rate=0.005)

# %%
M3.eval()
# Out:
# MF-MLP model test err = 0.865658663149873

# %%
M3.pplot()
